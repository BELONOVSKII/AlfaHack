# %%
import sys; sys.path.append("../../../../automl/")

# %%
from pathlib import Path
import yaml
import joblib

import pandas as pd
import numpy as np
import optuna

from sklearn.model_selection import train_test_split, StratifiedKFold, TimeSeriesSplit
from sklearn.metrics import roc_auc_score

# from src.automl.model.lama import TabularLama
# from src.automl.loggers import configure_root_logger
# from src.automl.constants import create_ml_data_dir
# from src.automl.model.metrics import RocAuc

# %%
optuna.logging.set_verbosity(optuna.logging.INFO)

# %%
# create_ml_data_dir()
# configure_root_logger()

# %% [markdown]
# ## Constants

# %%
RANDOM_SEED = 77
DATA_PATH = Path("../../../../data/")
CONFIG_PATH = Path("../../../../configs/config.yaml")
N_JOBS = 16

# %%
with CONFIG_PATH.open() as f:
    cfg = yaml.load(f, Loader=yaml.SafeLoader)

# %% [markdown]
# ## Data

# %%
df_train = pd.read_parquet(DATA_PATH / "train_preproc_oof.parquet")
#df_train, df_test = df_train.sort_values(by="id").iloc[:300_000], df_train.sort_values(by="id").iloc[300_000:]

# %%
df_train["target"].value_counts(normalize=True)
# Out:
# 0    0.940982
# 1    0.059018
# Name: target, dtype: float64

# %%
# undersample the 0 class
#df_train = pd.concat([df_train.loc[df_train.target == 1], df_train.loc[df_train.target == 0].sample(200_000, random_state=RANDOM_SEED)], ignore_index=True)

# %%
cat_columns = df_train.drop(columns=["target", "id"]).select_dtypes(int).columns.values.tolist()

# %%
X_train, y_train = df_train[cfg["selected_features"] + cfg["stack_features"] + cat_columns], df_train["target"]
#X_test, y_test = df_test[cfg["selected_features"] + cat_columns], df_test["target"]

# %%
display(y_train.value_counts(normalize=True))
#display(y_test.value_counts(normalize=True))
# Out:
# 0    0.940982
# 1    0.059018
# Name: target, dtype: float64

# %%
#categorical_features = ohe_cols# + oe_cols

# %% [markdown]
# ## Blend

# %%
cfg["stack_features"]
# Out:
# ['lamau_81425_full_dataset',
#  'lgb_8122_full_dataset',
#  'cb_8114_full_dataset',
#  'xgb_81325_full_dataset',
#  'lama_81298_full_dataset',
#  'lamann_autoint_8053_full_dataset',
#  'lamann_fttransformer_8050_full_dataset']

# %%
cfg["stack_features"] = ["lamau_81425_full_dataset", "xgb_81325_full_dataset", "lamann_autoint_8053_full_dataset"]

# %%
df_train[cfg["stack_features"]] = np.round(df_train[cfg["stack_features"]], 10)

# %%
def objective(trial):
    weights = []
    w0 = trial.suggest_float("w0", 0, 1)
    weights.append(w0)
    
    for i in range(1, len(cfg["stack_features"]) - 1):
        sum_prev_weights = np.sum(weights)
        wi = trial.suggest_float(f"w{i}", 0, sum_prev_weights)
        weights.append(wi)
        
    w6 = 1 - np.sum(weights)
    weights.append(w6)
    
    weights = np.array(weights)
    
    cv = kf.split(X_train, y_train)
    
    metrics = []
    for i, (train_idx, test_idx) in enumerate(cv):
    
        preds = np.sum(X_train.iloc[test_idx][cfg["stack_features"]].to_numpy() * weights, axis=1)
        metrics.append(metric(y_train.iloc[test_idx], preds))
        
    
    return np.mean(metrics)

# %%
def objective(trial):
    weights = []
    w0 = trial.suggest_float("w0", 0, 1)
    weights.append(w0)
    
    
        
    w1 = 1 - w0
    weights.append(w1)
    
    weights = np.array(weights)
    
    cv = kf.split(X_train, y_train)
    
    metrics = []
    for i, (train_idx, test_idx) in enumerate(cv):
    
        preds = np.sum(X_train.iloc[test_idx][cfg["stack_features"]].to_numpy() * weights, axis=1)
        metrics.append(metric(y_train.iloc[test_idx], preds))
        
    
    return np.mean(metrics)

# %%
def objective(trial):
    weights = []
    w0 = trial.suggest_float("w0", 0, 1)
    weights.append(w0)
    
    w1 = trial.suggest_float("w1", 0, 1 - w0)
    weights.append(w1)
        
    w2 = 1 - np.sum(weights)
    weights.append(w2)
    
    weights = np.array(weights)
    
    preds = np.round(np.sum(X_train[cfg["stack_features"]].to_numpy() * weights, axis=1), 10)
    
    res = metric(y_train, preds)
        
    
    return res

# %%
# kf = StratifiedKFold(
#                 n_splits=5, random_state=RANDOM_SEED, shuffle=True)

# kf = TimeSeriesSplit(
#                 n_splits=5)
metric = roc_auc_score

# %%
study = optuna.create_study(
            study_name="blending",
            direction="maximize")
study.optimize(objective, timeout=60, n_jobs=N_JOBS)
# Out:
# [I 2024-11-10 15:52:50,469] A new study created in memory with name: blending
# [I 2024-11-10 15:52:50,997] Trial 0 finished with value: 0.8141864519231701 and parameters: {'w0': 0.7011518554479736, 'w1': 0.1430507966057112}. Best is trial 0 with value: 0.8141864519231701.
# [I 2024-11-10 15:52:51,116] Trial 3 finished with value: 0.8143275781655728 and parameters: {'w0': 0.658533453533373, 'w1': 0.3143729202635799}. Best is trial 3 with value: 0.8143275781655728.
# [I 2024-11-10 15:52:51,117] Trial 5 finished with value: 0.8134965212270425 and parameters: {'w0': 0.3187691553573996, 'w1': 0.3893997870690148}. Best is trial 3 with value: 0.8143275781655728.
# [I 2024-11-10 15:52:51,144] Trial 4 finished with value: 0.8142632599872135 and parameters: {'w0': 0.617153084578135, 'w1': 0.2748973705057389}. Best is trial 3 with value: 0.8143275781655728.
# [I 2024-11-10 15:52:51,145] Trial 1 finished with value: 0.8128616392096611 and parameters: {'w0': 0.26225853421257506, 'w1': 0.33769660436789384}. Best is trial 3 with value: 0.8143275781655728.
# [I 2024-11-10 15:52:51,154] Trial 6 finished with value: 0.8131550832585245 and parameters: {'w0': 0.5889764583083488, 'w1': 0.03291427553181409}. Best is trial 3 with value: 0.8143275781655728.
# [I 2024-11-10 15:52:51,209] Trial 2 finished with value: 0.813466328921103 and parameters: {'w0': 0.06457833481395736, 'w1': 0.8156945671501185}. Best is trial 3 with value: 0.8143275781655728.
# [I 2024-11-10 15:52:51,246] Trial 8 finished with value: 0.8143539106277631 and parameters: {'w0': 0.77202073691956, 'w1': 0.19482829961580875}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,270] Trial 11 finished with value: 0.8141583766935914 and parameters: {'w0': 0.751396944608276, 'w1': 0.08504280690289176}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,274] Trial 10 finished with value: 0.8129943098028832 and parameters: {'w0': 0.33547040475185763, 'w1': 0.2745510295152893}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,280] Trial 14 finished with value: 0.8139961051055746 and parameters: {'w0': 0.42778175047120637, 'w1': 0.3942119264191519}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,281] Trial 9 finished with value: 0.8138245575843446 and parameters: {'w0': 0.22992314876394027, 'w1': 0.6697567370881106}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,315] Trial 7 finished with value: 0.8106178471327236 and parameters: {'w0': 0.31245739331963673, 'w1': 0.030914498259086116}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,317] Trial 13 finished with value: 0.807492689841744 and parameters: {'w0': 0.039668769303012, 'w1': 0.08248721152016004}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,318] Trial 12 finished with value: 0.8125386055566397 and parameters: {'w0': 0.3643728255426031, 'w1': 0.177262036167116}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,502] Trial 15 finished with value: 0.8141593732688183 and parameters: {'w0': 0.44727884492220726, 'w1': 0.4983461979893842}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,774] Trial 18 finished with value: 0.8143305756432149 and parameters: {'w0': 0.6639947407579021, 'w1': 0.30629582300406166}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,849] Trial 17 finished with value: 0.8140192115391104 and parameters: {'w0': 0.5792145262393046, 'w1': 0.21497874450727852}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,894] Trial 16 finished with value: 0.8117910066517723 and parameters: {'w0': 0.3547623104643425, 'w1': 0.09947703651282254}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:51,933] Trial 19 finished with value: 0.8128317820837482 and parameters: {'w0': 0.27454266532863514, 'w1': 0.31866232230771235}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,006] Trial 21 finished with value: 0.8143233285616636 and parameters: {'w0': 0.689055298545677, 'w1': 0.23554155469290702}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,007] Trial 20 finished with value: 0.8137475631040968 and parameters: {'w0': 0.5170381691056715, 'w1': 0.21301455668105634}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,013] Trial 22 finished with value: 0.8137724872406435 and parameters: {'w0': 0.5105789304210412, 'w1': 0.22592866242428739}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,035] Trial 23 finished with value: 0.8143274873041526 and parameters: {'w0': 0.7141694983564759, 'w1': 0.20989795236164005}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,103] Trial 24 finished with value: 0.8142613694052224 and parameters: {'w0': 0.918498750552889, 'w1': 0.000771615311833812}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,116] Trial 29 finished with value: 0.8142777035252652 and parameters: {'w0': 0.9470476634625047, 'w1': 0.0036000746724106428}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,135] Trial 27 finished with value: 0.8142742985159604 and parameters: {'w0': 0.9644951520054483, 'w1': 4.245427015157205e-05}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,153] Trial 25 finished with value: 0.8142710145849035 and parameters: {'w0': 0.9765115492469142, 'w1': 0.000989641031656406}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,176] Trial 31 finished with value: 0.8142616621867687 and parameters: {'w0': 0.917542860067542, 'w1': 0.0015419340047945138}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,206] Trial 26 finished with value: 0.8142692964444931 and parameters: {'w0': 0.9808918956562694, 'w1': 0.0034162634324271628}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,264] Trial 30 finished with value: 0.8142733149134029 and parameters: {'w0': 0.9722914401541528, 'w1': 0.001829831257695978}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,287] Trial 28 finished with value: 0.8142033008367023 and parameters: {'w0': 0.8729246663263391, 'w1': 0.0007521968794181322}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,653] Trial 35 finished with value: 0.8142602094060019 and parameters: {'w0': 0.9131509708429235, 'w1': 0.0029350365426462563}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,728] Trial 33 finished with value: 0.8142732164582251 and parameters: {'w0': 0.9382750571140683, 'w1': 0.001094085470886439}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,815] Trial 39 finished with value: 0.8142756572185071 and parameters: {'w0': 0.9370592137458231, 'w1': 0.0036366397030750085}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,819] Trial 41 finished with value: 0.814330770655131 and parameters: {'w0': 0.8375035463524193, 'w1': 0.10467471635247205}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,819] Trial 42 finished with value: 0.8143244283909012 and parameters: {'w0': 0.8102549319177048, 'w1': 0.11682727670341032}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,856] Trial 36 finished with value: 0.8142982970050863 and parameters: {'w0': 0.9419135820421761, 'w1': 0.0580450719310418}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,861] Trial 34 finished with value: 0.8142690931532718 and parameters: {'w0': 0.9198384053234906, 'w1': 0.0055449920373598915}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:52,879] Trial 32 finished with value: 0.8142763259437931 and parameters: {'w0': 0.9602143923766255, 'w1': 0.0021999790388920436}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,018] Trial 43 finished with value: 0.8143225371233628 and parameters: {'w0': 0.8172832730854868, 'w1': 0.10979339494645947}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,051] Trial 46 finished with value: 0.8143280871582753 and parameters: {'w0': 0.7907143248005002, 'w1': 0.13588113246956957}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,118] Trial 40 finished with value: 0.8143258879744093 and parameters: {'w0': 0.8246276272493711, 'w1': 0.1077941106117776}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,197] Trial 47 finished with value: 0.8143237415777065 and parameters: {'w0': 0.7906257468928604, 'w1': 0.1318198422434818}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,280] Trial 38 finished with value: 0.8142655893723829 and parameters: {'w0': 0.916123583548078, 'w1': 0.0048531519409197865}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,303] Trial 45 finished with value: 0.8143268899812826 and parameters: {'w0': 0.7944533130657545, 'w1': 0.13158437759169422}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,388] Trial 37 finished with value: 0.8142864821728193 and parameters: {'w0': 0.9591164616689037, 'w1': 0.04083412896305744}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,389] Trial 48 finished with value: 0.8143266538365124 and parameters: {'w0': 0.7938657083019621, 'w1': 0.1318790113545329}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,505] Trial 49 finished with value: 0.8143002039874846 and parameters: {'w0': 0.7735996301302878, 'w1': 0.1291485933674137}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,531] Trial 44 finished with value: 0.8143409796713201 and parameters: {'w0': 0.8321940603711453, 'w1': 0.1227950945951497}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,670] Trial 50 finished with value: 0.8140397963177508 and parameters: {'w0': 0.6461442011973453, 'w1': 0.14995352880640955}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,742] Trial 51 finished with value: 0.8140751225839631 and parameters: {'w0': 0.6452824474719282, 'w1': 0.16151199541265426}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,760] Trial 53 finished with value: 0.8143347064891915 and parameters: {'w0': 0.8092554077223423, 'w1': 0.1283345192416925}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,763] Trial 54 finished with value: 0.8143373801774436 and parameters: {'w0': 0.8134239869929566, 'w1': 0.12850425252251388}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,829] Trial 52 finished with value: 0.8143332623041364 and parameters: {'w0': 0.7996365418309506, 'w1': 0.13405634386985893}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,904] Trial 56 finished with value: 0.8141589224949247 and parameters: {'w0': 0.6785015810539753, 'w1': 0.1555446850506079}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:53,970] Trial 58 finished with value: 0.8140001152424448 and parameters: {'w0': 0.652108571947472, 'w1': 0.13271504417369254}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,006] Trial 57 finished with value: 0.8140638196447922 and parameters: {'w0': 0.6603044294482882, 'w1': 0.14264789936996056}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,006] Trial 59 finished with value: 0.8140155577815071 and parameters: {'w0': 0.6389900128955103, 'w1': 0.15031466269672034}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,177] Trial 55 finished with value: 0.8143389304641685 and parameters: {'w0': 0.8252205997073088, 'w1': 0.12317531534557366}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,230] Trial 63 finished with value: 0.8141429482873556 and parameters: {'w0': 0.6538075959644276, 'w1': 0.17524826390371614}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,310] Trial 61 finished with value: 0.8141128603428498 and parameters: {'w0': 0.6516438611027839, 'w1': 0.16706856398925277}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,344] Trial 62 finished with value: 0.8143177205188799 and parameters: {'w0': 0.64523491741056, 'w1': 0.29241426477106497}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,413] Trial 60 finished with value: 0.8141023679845771 and parameters: {'w0': 0.6518515879535037, 'w1': 0.16335871809098718}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,459] Trial 64 finished with value: 0.8140468390006579 and parameters: {'w0': 0.6335932073112368, 'w1': 0.16500922474108157}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,508] Trial 66 finished with value: 0.8142821998735645 and parameters: {'w0': 0.7315862195592635, 'w1': 0.15744044249666725}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,632] Trial 67 finished with value: 0.8143282167267657 and parameters: {'w0': 0.8634845729303372, 'w1': 0.08844372531864972}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,666] Trial 68 finished with value: 0.8143272657140846 and parameters: {'w0': 0.8568011358124737, 'w1': 0.09039342156295785}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,670] Trial 71 finished with value: 0.8143315563981135 and parameters: {'w0': 0.8620630226575354, 'w1': 0.09459754561768982}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,672] Trial 69 finished with value: 0.814331228970048 and parameters: {'w0': 0.8754113018156946, 'w1': 0.09114527340288126}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,682] Trial 70 finished with value: 0.8143033279750204 and parameters: {'w0': 0.7277094992862783, 'w1': 0.17463890647710814}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,823] Trial 65 finished with value: 0.8140222682375157 and parameters: {'w0': 0.626502486814758, 'w1': 0.16507726761942643}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,840] Trial 74 finished with value: 0.8143288065086124 and parameters: {'w0': 0.8635452082110401, 'w1': 0.08961909226624291}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,855] Trial 73 finished with value: 0.8143274131595464 and parameters: {'w0': 0.8605440213590406, 'w1': 0.08882598099989947}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,886] Trial 72 finished with value: 0.814339950980826 and parameters: {'w0': 0.857766539212235, 'w1': 0.12087123726515055}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:54,968] Trial 76 finished with value: 0.8143420368384052 and parameters: {'w0': 0.8488012339801626, 'w1': 0.12349539273569789}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,129] Trial 75 finished with value: 0.8141069801904157 and parameters: {'w0': 0.7319427980878154, 'w1': 0.08627032116163172}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,219] Trial 77 finished with value: 0.8143406730733536 and parameters: {'w0': 0.8558222548893373, 'w1': 0.12379744683984632}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,249] Trial 78 finished with value: 0.8141175839238011 and parameters: {'w0': 0.7246645720949038, 'w1': 0.09644751919832424}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,360] Trial 80 finished with value: 0.8140932560027014 and parameters: {'w0': 0.7253810832673105, 'w1': 0.0881512515540328}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,463] Trial 86 finished with value: 0.8143246806724066 and parameters: {'w0': 0.8866986274135517, 'w1': 0.07736993989397109}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,502] Trial 84 finished with value: 0.8143206606214641 and parameters: {'w0': 0.8878564782314502, 'w1': 0.069754171483443}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,517] Trial 83 finished with value: 0.8142393444493436 and parameters: {'w0': 0.7480665268278935, 'w1': 0.11988659513553582}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,725] Trial 79 finished with value: 0.8143390935717554 and parameters: {'w0': 0.8610369503631027, 'w1': 0.12161929371525859}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,763] Trial 90 finished with value: 0.8142420080653199 and parameters: {'w0': 0.7521831924383513, 'w1': 0.11727324445551594}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,776] Trial 85 finished with value: 0.814323472052043 and parameters: {'w0': 0.8813958528430661, 'w1': 0.07570823001117008}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,820] Trial 88 finished with value: 0.814322214599599 and parameters: {'w0': 0.8867303357651832, 'w1': 0.0727639258951373}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,827] Trial 89 finished with value: 0.8142714705267711 and parameters: {'w0': 0.7630753368766641, 'w1': 0.12164164713392928}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,878] Trial 82 finished with value: 0.8143413276130783 and parameters: {'w0': 0.8529774701332773, 'w1': 0.12355847067315552}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,927] Trial 91 finished with value: 0.814279649003796 and parameters: {'w0': 0.7671415514364179, 'w1': 0.12253080037519838}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,993] Trial 92 finished with value: 0.8142580390678684 and parameters: {'w0': 0.7560314526972888, 'w1': 0.12132021872826217}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:55,994] Trial 81 finished with value: 0.8143379867288386 and parameters: {'w0': 0.8639234715639903, 'w1': 0.12058105926190753}. Best is trial 8 with value: 0.8143539106277631.
# /home/peter/venvs/base_venv/lib/python3.10/site-packages/optuna/samplers/_tpe/sampler.py:512: RuntimeWarning: invalid value encountered in subtract
#   acq_func_vals = log_likelihoods_below - log_likelihoods_above
# [I 2024-11-10 15:52:56,111] Trial 93 finished with value: 0.8129567299308751 and parameters: {'w0': 0.13030575777865405, 'w1': 0.5191303759888406}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,162] Trial 87 finished with value: 0.8087655817136563 and parameters: {'w0': 0.14388791200177242, 'w1': 0.0600546723706773}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,199] Trial 95 finished with value: 0.8109544692877753 and parameters: {'w0': 0.14198268099378508, 'w1': 0.24176707610474338}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,200] Trial 94 finished with value: 0.8143255750483116 and parameters: {'w0': 0.8919187451127885, 'w1': 0.10373082077632231}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,392] Trial 97 finished with value: 0.8142608317777253 and parameters: {'w0': 0.7579969531614844, 'w1': 0.12093014359967455}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,393] Trial 96 finished with value: 0.8142639274468733 and parameters: {'w0': 0.7586049975297263, 'w1': 0.12187493850420159}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,473] Trial 98 finished with value: 0.811139178531307 and parameters: {'w0': 0.19898528037106378, 'w1': 0.19766822138522683}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,592] Trial 101 finished with value: 0.8110214349981101 and parameters: {'w0': 0.18370227274209783, 'w1': 0.2027240494923862}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,595] Trial 102 finished with value: 0.8138810253992919 and parameters: {'w0': 0.5686326364263717, 'w1': 0.18866168550188278}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,760] Trial 100 finished with value: 0.8143414447362436 and parameters: {'w0': 0.8330188700404375, 'w1': 0.12317852564426432}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,781] Trial 105 finished with value: 0.8143335234977602 and parameters: {'w0': 0.8324236966954993, 'w1': 0.11101346079763667}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,796] Trial 104 finished with value: 0.8139434878003827 and parameters: {'w0': 0.9972410170108925, 'w1': 0.15550313174812053}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,803] Trial 103 finished with value: 0.8143355971736864 and parameters: {'w0': 0.8352514374436957, 'w1': 0.11224629441397951}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:56,971] Trial 99 finished with value: 0.8104532723685485 and parameters: {'w0': 0.13359467575107697, 'w1': 0.20426796598671826}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,004] Trial 108 finished with value: 0.8143393830837671 and parameters: {'w0': 0.8461657583860565, 'w1': 0.11422474509669389}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,038] Trial 110 finished with value: 0.8143364240495231 and parameters: {'w0': 0.8360420152658313, 'w1': 0.11317562411518857}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,067] Trial 111 finished with value: 0.8143431254352098 and parameters: {'w0': 0.8417201076650325, 'w1': 0.1253156190699964}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,197] Trial 107 finished with value: 0.8143367454658639 and parameters: {'w0': 0.8364640466591842, 'w1': 0.11342212569770406}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,231] Trial 112 finished with value: 0.8143354280016403 and parameters: {'w0': 0.8335474668698404, 'w1': 0.11310631946792703}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,232] Trial 113 finished with value: 0.8143369966926804 and parameters: {'w0': 0.8373328488492938, 'w1': 0.11326897679266877}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,280] Trial 114 finished with value: 0.8143348747647525 and parameters: {'w0': 0.8345140441962217, 'w1': 0.111663832040921}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,309] Trial 106 finished with value: 0.8143364457761076 and parameters: {'w0': 0.836999168686126, 'w1': 0.1127264995326311}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,365] Trial 109 finished with value: 0.8143434205898055 and parameters: {'w0': 0.8400732848579328, 'w1': 0.12665710942511155}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,440] Trial 115 finished with value: 0.8143373575543739 and parameters: {'w0': 0.8366623461915388, 'w1': 0.11428661947523064}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,598] Trial 116 finished with value: 0.8143437971663583 and parameters: {'w0': 0.8383331432178247, 'w1': 0.12790373597233945}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,604] Trial 117 finished with value: 0.8143431975231734 and parameters: {'w0': 0.8446031777776499, 'w1': 0.12586161500523008}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,624] Trial 119 finished with value: 0.8142904163193782 and parameters: {'w0': 0.908261654804508, 'w1': 0.027705213503893933}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,732] Trial 118 finished with value: 0.814346789528761 and parameters: {'w0': 0.8326301786562827, 'w1': 0.13935808909432423}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,755] Trial 120 finished with value: 0.8143448564955551 and parameters: {'w0': 0.8420661081634432, 'w1': 0.13910647617828212}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,912] Trial 122 finished with value: 0.8143432447732213 and parameters: {'w0': 0.8435131475270748, 'w1': 0.12603424485593623}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:57,950] Trial 121 finished with value: 0.8143433612635734 and parameters: {'w0': 0.8423093489973049, 'w1': 0.1263633597373715}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,043] Trial 123 finished with value: 0.8142791835169971 and parameters: {'w0': 0.9083247521597092, 'w1': 0.018391238582800302}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,120] Trial 126 finished with value: 0.8142852643239309 and parameters: {'w0': 0.9102367239190329, 'w1': 0.022042282487058362}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,147] Trial 125 finished with value: 0.8142908716811671 and parameters: {'w0': 0.9077765254944582, 'w1': 0.028320036089175882}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,153] Trial 128 finished with value: 0.8143040551827874 and parameters: {'w0': 0.91481601612353, 'w1': 0.04039304585401704}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,181] Trial 127 finished with value: 0.814285446415912 and parameters: {'w0': 0.918220792571101, 'w1': 0.019094439939983082}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,414] Trial 124 finished with value: 0.8142988752380932 and parameters: {'w0': 0.9070898158149608, 'w1': 0.036356846374290624}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,445] Trial 129 finished with value: 0.8142867703664705 and parameters: {'w0': 0.913862003240696, 'w1': 0.021994577994459086}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,530] Trial 131 finished with value: 0.8142825526668904 and parameters: {'w0': 0.9088809083078501, 'w1': 0.02058028827081132}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,653] Trial 134 finished with value: 0.8143285967310565 and parameters: {'w0': 0.7874966120947102, 'w1': 0.13907531828295677}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,671] Trial 130 finished with value: 0.8143192441747183 and parameters: {'w0': 0.9048120655135601, 'w1': 0.09264081151874}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,725] Trial 132 finished with value: 0.814325109403309 and parameters: {'w0': 0.7825387322467173, 'w1': 0.14023141505088352}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,779] Trial 133 finished with value: 0.8143039682237151 and parameters: {'w0': 0.9279993324361415, 'w1': 0.04242676611113658}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,867] Trial 136 finished with value: 0.8143274360990228 and parameters: {'w0': 0.7847288422513969, 'w1': 0.14045568251270135}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,890] Trial 135 finished with value: 0.8143312978939458 and parameters: {'w0': 0.7874653835606442, 'w1': 0.14168506667524097}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,926] Trial 138 finished with value: 0.8143231218427043 and parameters: {'w0': 0.7805013143431161, 'w1': 0.14025299044047426}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:58,968] Trial 139 finished with value: 0.8143278431560752 and parameters: {'w0': 0.8008495675049137, 'w1': 0.12714796938105763}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,119] Trial 137 finished with value: 0.8143169337739431 and parameters: {'w0': 0.908705645928181, 'w1': 0.09005399208713377}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,281] Trial 142 finished with value: 0.8143248032272181 and parameters: {'w0': 0.7839476844853212, 'w1': 0.13870522040534092}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,311] Trial 141 finished with value: 0.8143379403225416 and parameters: {'w0': 0.8002974703898026, 'w1': 0.13899553241581528}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,348] Trial 145 finished with value: 0.8143352078881363 and parameters: {'w0': 0.7963661558033266, 'w1': 0.13888944487557764}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,446] Trial 140 finished with value: 0.8143236589955916 and parameters: {'w0': 0.7804541717940099, 'w1': 0.14077278326714296}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,569] Trial 147 finished with value: 0.8143395245702384 and parameters: {'w0': 0.8045042704183664, 'w1': 0.13794881137737117}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,688] Trial 148 finished with value: 0.814336539274249 and parameters: {'w0': 0.814644655042821, 'w1': 0.12655951513715658}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,693] Trial 146 finished with value: 0.8143278891932311 and parameters: {'w0': 0.7860924362814892, 'w1': 0.13969549473636422}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,694] Trial 144 finished with value: 0.8143265975688774 and parameters: {'w0': 0.7837344793692045, 'w1': 0.14055346071505054}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,719] Trial 143 finished with value: 0.8143271407334894 and parameters: {'w0': 0.7847155494480096, 'w1': 0.14022374307039864}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,766] Trial 150 finished with value: 0.8143334377515796 and parameters: {'w0': 0.8066899539514097, 'w1': 0.12872637570168546}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,790] Trial 152 finished with value: 0.8143332058255637 and parameters: {'w0': 0.8102222888105501, 'w1': 0.12591959427463195}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,859] Trial 149 finished with value: 0.8143330329621075 and parameters: {'w0': 0.8100113338836631, 'w1': 0.12589802901898572}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,979] Trial 154 finished with value: 0.8129986998385752 and parameters: {'w0': 0.42105130255647866, 'w1': 0.1809843064784989}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:52:59,985] Trial 151 finished with value: 0.8143306667155725 and parameters: {'w0': 0.8071974389399522, 'w1': 0.12522344920710654}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,049] Trial 153 finished with value: 0.8143481080476732 and parameters: {'w0': 0.8150757775301511, 'w1': 0.14703228908089594}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,171] Trial 155 finished with value: 0.8143328791885144 and parameters: {'w0': 0.8101003760790333, 'w1': 0.12554081823409674}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,274] Trial 156 finished with value: 0.8143388696086381 and parameters: {'w0': 0.8201816978803081, 'w1': 0.1263109354370809}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,317] Trial 158 finished with value: 0.8131155899177834 and parameters: {'w0': 0.43362096663362987, 'w1': 0.185505811857895}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,483] Trial 161 finished with value: 0.8143345712253827 and parameters: {'w0': 0.8715584643750682, 'w1': 0.11817857030414232}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,492] Trial 160 finished with value: 0.8143325480690389 and parameters: {'w0': 0.8755921566165298, 'w1': 0.1177886220895641}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,612] Trial 162 finished with value: 0.8143330547941607 and parameters: {'w0': 0.8744347192792349, 'w1': 0.1184430103756373}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,644] Trial 159 finished with value: 0.8143364574831506 and parameters: {'w0': 0.8122591179245728, 'w1': 0.12810207037822097}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,709] Trial 157 finished with value: 0.8143344517819024 and parameters: {'w0': 0.81271454905932, 'w1': 0.12551651895882668}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,722] Trial 166 finished with value: 0.8143339387813834 and parameters: {'w0': 0.8707442072531735, 'w1': 0.12411160541724776}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,744] Trial 165 finished with value: 0.8143342645219473 and parameters: {'w0': 0.870097281141707, 'w1': 0.1241239529072309}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,897] Trial 170 finished with value: 0.8143401405610959 and parameters: {'w0': 0.8562683968816962, 'w1': 0.1311428390050998}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,907] Trial 168 finished with value: 0.8143398171935814 and parameters: {'w0': 0.8570960195416509, 'w1': 0.13086020440635465}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,963] Trial 164 finished with value: 0.8143346296551294 and parameters: {'w0': 0.8719943657451448, 'w1': 0.11654789002944702}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,964] Trial 169 finished with value: 0.8143319210566856 and parameters: {'w0': 0.8765242774893699, 'w1': 0.11807619806399068}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:00,986] Trial 171 finished with value: 0.814332383379419 and parameters: {'w0': 0.8759878045174424, 'w1': 0.11739225997442919}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,067] Trial 167 finished with value: 0.8143377613418918 and parameters: {'w0': 0.8647009012811004, 'w1': 0.11745891696718115}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,083] Trial 173 finished with value: 0.814333848500042 and parameters: {'w0': 0.8735586516046092, 'w1': 0.11724779334811716}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,133] Trial 163 finished with value: 0.8143339471661576 and parameters: {'w0': 0.8731946784664208, 'w1': 0.11780336331143246}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,281] Trial 172 finished with value: 0.8143341812015505 and parameters: {'w0': 0.8725061765953912, 'w1': 0.11706807729442088}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,325] Trial 174 finished with value: 0.8143411178882568 and parameters: {'w0': 0.8532228034694368, 'w1': 0.13493841906030402}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,463] Trial 176 finished with value: 0.8143427865637733 and parameters: {'w0': 0.8489796203537988, 'w1': 0.135367556735051}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,545] Trial 177 finished with value: 0.8143372893160236 and parameters: {'w0': 0.8618210959448638, 'w1': 0.13124388525133443}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,609] Trial 179 finished with value: 0.8143409705482638 and parameters: {'w0': 0.8536189128981285, 'w1': 0.13427921103272913}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,703] Trial 180 finished with value: 0.8143421091373064 and parameters: {'w0': 0.8512454230670894, 'w1': 0.13219823675778486}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,734] Trial 181 finished with value: 0.8143424127294107 and parameters: {'w0': 0.8501649959688011, 'w1': 0.1339167957287964}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,805] Trial 182 finished with value: 0.8143427812903304 and parameters: {'w0': 0.8487985933546363, 'w1': 0.13504269779108524}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,806] Trial 175 finished with value: 0.8143430382651998 and parameters: {'w0': 0.8480553678246923, 'w1': 0.13447098877827154}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,869] Trial 185 finished with value: 0.8143446891692139 and parameters: {'w0': 0.8418561109983036, 'w1': 0.14506501557506182}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,871] Trial 178 finished with value: 0.8143395808378734 and parameters: {'w0': 0.8566688015845867, 'w1': 0.13415828418475073}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:01,927] Trial 184 finished with value: 0.8143442389226647 and parameters: {'w0': 0.8443979709450595, 'w1': 0.1350336700814588}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,053] Trial 188 finished with value: 0.8143445096612197 and parameters: {'w0': 0.8428749598646487, 'w1': 0.1349564924570839}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,123] Trial 190 finished with value: 0.8143396039882874 and parameters: {'w0': 0.8563141777265151, 'w1': 0.13481179546451671}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,221] Trial 183 finished with value: 0.8143417175314416 and parameters: {'w0': 0.851751150649024, 'w1': 0.13403347052618345}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,243] Trial 187 finished with value: 0.8143436069532751 and parameters: {'w0': 0.8464525484106188, 'w1': 0.1345810128332209}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,336] Trial 189 finished with value: 0.814343360103416 and parameters: {'w0': 0.8468189297972182, 'w1': 0.13106811837524113}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,365] Trial 186 finished with value: 0.8143430158530678 and parameters: {'w0': 0.8481307979581876, 'w1': 0.13348241999122423}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,419] Trial 192 finished with value: 0.8143448338197509 and parameters: {'w0': 0.841276494994175, 'w1': 0.1350557932464231}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,551] Trial 193 finished with value: 0.8143425732002761 and parameters: {'w0': 0.8495703619319067, 'w1': 0.1344186862675276}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,565] Trial 191 finished with value: 0.8143440232915871 and parameters: {'w0': 0.8451681481455284, 'w1': 0.13475744770604947}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,798] Trial 199 finished with value: 0.8143477472387144 and parameters: {'w0': 0.8311305059395314, 'w1': 0.14869480990570932}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,839] Trial 198 finished with value: 0.8143469446207148 and parameters: {'w0': 0.8343417370292883, 'w1': 0.14542860305456815}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:02,903] Trial 195 finished with value: 0.81434426840121 and parameters: {'w0': 0.8413998483455792, 'w1': 0.14772435874679377}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,002] Trial 194 finished with value: 0.8143435140879468 and parameters: {'w0': 0.8438260420185361, 'w1': 0.14564204334559835}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,081] Trial 197 finished with value: 0.8143438542250097 and parameters: {'w0': 0.8458878180616324, 'w1': 0.13518089759966895}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,094] Trial 202 finished with value: 0.8143480436062018 and parameters: {'w0': 0.8288793259271783, 'w1': 0.147032091158639}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,179] Trial 196 finished with value: 0.814343116206685 and parameters: {'w0': 0.8478466874713324, 'w1': 0.13477269578770146}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,293] Trial 203 finished with value: 0.8143476514729926 and parameters: {'w0': 0.831527698010367, 'w1': 0.14878452219061145}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,338] Trial 207 finished with value: 0.8143479269576461 and parameters: {'w0': 0.8294732472585429, 'w1': 0.14538471368222786}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,358] Trial 200 finished with value: 0.8143478223852747 and parameters: {'w0': 0.8298873743777343, 'w1': 0.145926043686932}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,428] Trial 205 finished with value: 0.8143484107960265 and parameters: {'w0': 0.8237727278846049, 'w1': 0.14623656469657045}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,485] Trial 201 finished with value: 0.8143475063478456 and parameters: {'w0': 0.8317647642056086, 'w1': 0.1462654725754766}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,512] Trial 208 finished with value: 0.8143478731685294 and parameters: {'w0': 0.8295040562813853, 'w1': 0.146375534337402}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,530] Trial 204 finished with value: 0.8143480861628855 and parameters: {'w0': 0.8286935022300727, 'w1': 0.1467572173446717}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,561] Trial 206 finished with value: 0.8143479369244532 and parameters: {'w0': 0.8301712403125656, 'w1': 0.148377119200065}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,761] Trial 210 finished with value: 0.8143485170558995 and parameters: {'w0': 0.8261024868533536, 'w1': 0.14672577018565222}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,808] Trial 209 finished with value: 0.8143474023028185 and parameters: {'w0': 0.8317788001951958, 'w1': 0.1459963473286784}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,951] Trial 214 finished with value: 0.8143489659313538 and parameters: {'w0': 0.8215469408215178, 'w1': 0.14831441343587953}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,952] Trial 212 finished with value: 0.8143473629629349 and parameters: {'w0': 0.8318307454764432, 'w1': 0.1458337805948191}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:03,963] Trial 213 finished with value: 0.8143485040304957 and parameters: {'w0': 0.8263239466729047, 'w1': 0.1463142077693064}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,042] Trial 215 finished with value: 0.8143484860480557 and parameters: {'w0': 0.8260502275118142, 'w1': 0.1461836912643485}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,153] Trial 216 finished with value: 0.814348515262929 and parameters: {'w0': 0.8237841602360454, 'w1': 0.14688182222964144}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,247] Trial 211 finished with value: 0.8143476376038379 and parameters: {'w0': 0.8306907743886187, 'w1': 0.14523644389835283}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,276] Trial 217 finished with value: 0.8143483889112386 and parameters: {'w0': 0.8273952132238567, 'w1': 0.14611745605438042}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,278] Trial 218 finished with value: 0.8143486369739896 and parameters: {'w0': 0.8218599229414155, 'w1': 0.14681569752396723}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,447] Trial 222 finished with value: 0.8143485462707728 and parameters: {'w0': 0.8189858964773593, 'w1': 0.1467241361729626}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,524] Trial 223 finished with value: 0.8143478269204356 and parameters: {'w0': 0.8304510751124673, 'w1': 0.14663437911223562}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,632] Trial 219 finished with value: 0.8143488736988385 and parameters: {'w0': 0.8224315491165501, 'w1': 0.14822718583827388}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,709] Trial 224 finished with value: 0.8143484195499415 and parameters: {'w0': 0.8275869960575156, 'w1': 0.14666039479843343}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,710] Trial 225 finished with value: 0.8143482499032855 and parameters: {'w0': 0.8152033488882338, 'w1': 0.14730778477331552}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,908] Trial 220 finished with value: 0.8143484662199107 and parameters: {'w0': 0.8226655397074811, 'w1': 0.14603835840074936}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,916] Trial 229 finished with value: 0.8143496078675501 and parameters: {'w0': 0.8157531671350697, 'w1': 0.15176040084980852}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,964] Trial 227 finished with value: 0.814349960449938 and parameters: {'w0': 0.819854052043687, 'w1': 0.15285884498720131}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,971] Trial 221 finished with value: 0.8143486992006151 and parameters: {'w0': 0.8242774588861534, 'w1': 0.14743149734938626}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:04,981] Trial 228 finished with value: 0.8143494980744702 and parameters: {'w0': 0.8233824390357909, 'w1': 0.1526556988650232}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,048] Trial 230 finished with value: 0.8143493238399191 and parameters: {'w0': 0.8238874125839876, 'w1': 0.15179738620408872}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,069] Trial 231 finished with value: 0.814349623740613 and parameters: {'w0': 0.8221598764641075, 'w1': 0.1527278520703235}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,120] Trial 226 finished with value: 0.8143486120833394 and parameters: {'w0': 0.8202131408861604, 'w1': 0.14654371095152394}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,132] Trial 233 finished with value: 0.8143497091176526 and parameters: {'w0': 0.81828002465467, 'w1': 0.15166460438904728}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,163] Trial 234 finished with value: 0.8143498631549179 and parameters: {'w0': 0.8182102988424141, 'w1': 0.15220372660589546}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,226] Trial 235 finished with value: 0.8143498296158214 and parameters: {'w0': 0.8196404297348892, 'w1': 0.152151518432059}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,238] Trial 232 finished with value: 0.8143497210356334 and parameters: {'w0': 0.8210503121778705, 'w1': 0.1520862208850368}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,425] Trial 237 finished with value: 0.8143497071664787 and parameters: {'w0': 0.817325234479062, 'w1': 0.1512798750244478}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,428] Trial 236 finished with value: 0.8143500201453111 and parameters: {'w0': 0.8177506547782759, 'w1': 0.15304327950618987}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,516] Trial 238 finished with value: 0.8143495009748638 and parameters: {'w0': 0.8120325492395327, 'w1': 0.15213185223501718}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,561] Trial 239 finished with value: 0.8143497586352807 and parameters: {'w0': 0.8160026256183239, 'w1': 0.15227543452460082}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,587] Trial 240 finished with value: 0.8143488248140234 and parameters: {'w0': 0.8043181259330477, 'w1': 0.15376913830877126}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,682] Trial 241 finished with value: 0.8143495357268521 and parameters: {'w0': 0.8099757008897038, 'w1': 0.1533297803188882}. Best is trial 8 with value: 0.8143539106277631.
# [I 2024-11-10 15:53:05,717] Trial 242 finished with value: 0.8143276702926191 and parameters: {'w0': 0.7641032616057403, 'w1': 0.1589296015164219}. Best is trial 8 with value: 0.8143539106277631.
# ...
# [I 2024-11-10 15:53:45,721] Trial 781 finished with value: 0.814346338596664 and parameters: {'w0': 0.7412079901099621, 'w1': 0.20518434001607808}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:45,723] Trial 785 finished with value: 0.8143342976391684 and parameters: {'w0': 0.7148708933713649, 'w1': 0.21735960830618561}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:45,727] Trial 783 finished with value: 0.8143183630878894 and parameters: {'w0': 0.7120368967566912, 'w1': 0.20311471726890185}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:45,870] Trial 778 finished with value: 0.8143494355841725 and parameters: {'w0': 0.7474970940642176, 'w1': 0.2049243006542762}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:45,877] Trial 779 finished with value: 0.8143432239958566 and parameters: {'w0': 0.7366294609683546, 'w1': 0.20471735128050889}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:45,964] Trial 784 finished with value: 0.8143540732607402 and parameters: {'w0': 0.7641903427061699, 'w1': 0.20141059874652242}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:46,071] Trial 787 finished with value: 0.814354471511143 and parameters: {'w0': 0.7694501817815248, 'w1': 0.20167693724633573}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:46,124] Trial 786 finished with value: 0.8143540393525026 and parameters: {'w0': 0.7650689575069778, 'w1': 0.20116326382971667}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:46,361] Trial 788 finished with value: 0.8143251002275187 and parameters: {'w0': 0.7203419228558647, 'w1': 0.20050576399805295}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:46,415] Trial 789 finished with value: 0.8143194806358951 and parameters: {'w0': 0.714217974835806, 'w1': 0.20187069835032945}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:46,514] Trial 791 finished with value: 0.8143316541677437 and parameters: {'w0': 0.7111253713641793, 'w1': 0.21813949390330084}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:46,587] Trial 790 finished with value: 0.8143542494991998 and parameters: {'w0': 0.7676619824890129, 'w1': 0.20061279463680667}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:46,654] Trial 792 finished with value: 0.8143544441419748 and parameters: {'w0': 0.7671783667031237, 'w1': 0.20262512126387675}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:46,791] Trial 793 finished with value: 0.8143199022476498 and parameters: {'w0': 0.7146533008354055, 'w1': 0.20174286749537457}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,051] Trial 796 finished with value: 0.8143544635482445 and parameters: {'w0': 0.770743643879021, 'w1': 0.20038878904754223}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,180] Trial 798 finished with value: 0.8143542507120916 and parameters: {'w0': 0.7674584972854733, 'w1': 0.20074735455155066}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,185] Trial 794 finished with value: 0.8143544438783026 and parameters: {'w0': 0.7702416360625999, 'w1': 0.2002572913227776}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,194] Trial 795 finished with value: 0.8143543320285801 and parameters: {'w0': 0.7680803818526498, 'w1': 0.20085870420282606}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,260] Trial 801 finished with value: 0.8143544470951027 and parameters: {'w0': 0.7700702564954809, 'w1': 0.2002704613533524}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,356] Trial 802 finished with value: 0.8143543222199764 and parameters: {'w0': 0.7685514081792284, 'w1': 0.2002982792815608}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,423] Trial 803 finished with value: 0.8143541089092137 and parameters: {'w0': 0.7666398816224744, 'w1': 0.20039763538999356}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,467] Trial 797 finished with value: 0.8143543692063522 and parameters: {'w0': 0.7676404303119112, 'w1': 0.20082800367143566}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,499] Trial 799 finished with value: 0.8143542660050758 and parameters: {'w0': 0.7678887105772294, 'w1': 0.20045224354497124}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,548] Trial 800 finished with value: 0.8143542332569957 and parameters: {'w0': 0.7683024419008608, 'w1': 0.19976485905842234}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,598] Trial 805 finished with value: 0.8143542395323928 and parameters: {'w0': 0.7686328622400266, 'w1': 0.19972608732038508}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,657] Trial 804 finished with value: 0.8143030321348773 and parameters: {'w0': 0.9340149174156386, 'w1': 0.06592189836337473}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,658] Trial 806 finished with value: 0.8143545099545413 and parameters: {'w0': 0.7710877325476769, 'w1': 0.20035176611873992}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,659] Trial 807 finished with value: 0.8143545386948048 and parameters: {'w0': 0.7702262030065921, 'w1': 0.20090185560129828}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,883] Trial 810 finished with value: 0.8143543772219852 and parameters: {'w0': 0.7699814156307444, 'w1': 0.2001843279122795}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:47,936] Trial 808 finished with value: 0.8143545123275906 and parameters: {'w0': 0.7705236266323028, 'w1': 0.2004646685156256}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,083] Trial 809 finished with value: 0.8143543756926868 and parameters: {'w0': 0.768444722092387, 'w1': 0.20110978420066544}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,089] Trial 812 finished with value: 0.8143541154482827 and parameters: {'w0': 0.7669049964898278, 'w1': 0.20015356379519647}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,094] Trial 811 finished with value: 0.8139181102532211 and parameters: {'w0': 0.5396092844092567, 'w1': 0.23024664437038805}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,166] Trial 813 finished with value: 0.8143544057513109 and parameters: {'w0': 0.7678267261843885, 'w1': 0.2021887102945665}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,204] Trial 817 finished with value: 0.8143540364521091 and parameters: {'w0': 0.7645688588079461, 'w1': 0.20152361278421332}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,205] Trial 815 finished with value: 0.8143544341751678 and parameters: {'w0': 0.7671841400701171, 'w1': 0.20291578149907394}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,268] Trial 814 finished with value: 0.8137575133524458 and parameters: {'w0': 0.5062544847745818, 'w1': 0.22725992470651532}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,316] Trial 816 finished with value: 0.8143542000870404 and parameters: {'w0': 0.7660472245862899, 'w1': 0.201540141657135}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,354] Trial 818 finished with value: 0.8139208671564011 and parameters: {'w0': 0.543302170601893, 'w1': 0.22685490731681102}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,410] Trial 819 finished with value: 0.8143542650031217 and parameters: {'w0': 0.7658929183623361, 'w1': 0.20183824820009522}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,422] Trial 820 finished with value: 0.8143541860596824 and parameters: {'w0': 0.7641264556669819, 'w1': 0.2032653731671754}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,450] Trial 823 finished with value: 0.8143460056314835 and parameters: {'w0': 0.7319981954434224, 'w1': 0.21544910758747438}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,477] Trial 821 finished with value: 0.8143327167664751 and parameters: {'w0': 0.7247109558083153, 'w1': 0.20383068706667323}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,496] Trial 822 finished with value: 0.8137535136042583 and parameters: {'w0': 0.5076820466209266, 'w1': 0.22475261891264822}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,567] Trial 824 finished with value: 0.8143534258401632 and parameters: {'w0': 0.7603191988384493, 'w1': 0.20323022439403263}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:48,606] Trial 825 finished with value: 0.8143532091016625 and parameters: {'w0': 0.7578899175888514, 'w1': 0.2043543981072339}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,008] Trial 827 finished with value: 0.8143403918406471 and parameters: {'w0': 0.7321155875366868, 'w1': 0.2054455513321659}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,013] Trial 826 finished with value: 0.8143465571281353 and parameters: {'w0': 0.7334217268353436, 'w1': 0.21496180919793823}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,142] Trial 831 finished with value: 0.8143457958539273 and parameters: {'w0': 0.7323023868454982, 'w1': 0.21459097658334533}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,143] Trial 828 finished with value: 0.8143434200097266 and parameters: {'w0': 0.7262725556814256, 'w1': 0.21741739142954045}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,200] Trial 832 finished with value: 0.8143463996103977 and parameters: {'w0': 0.731461849964166, 'w1': 0.21703069471352243}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,290] Trial 836 finished with value: 0.8143467972279875 and parameters: {'w0': 0.7343474010319977, 'w1': 0.214300977115589}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,291] Trial 829 finished with value: 0.8143458586078972 and parameters: {'w0': 0.7318744569632308, 'w1': 0.21530846243561572}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,321] Trial 833 finished with value: 0.814345096911814 and parameters: {'w0': 0.7310039251866444, 'w1': 0.21472507292494047}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,378] Trial 834 finished with value: 0.8143491819315722 and parameters: {'w0': 0.7376560148566624, 'w1': 0.21581343850140897}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,383] Trial 837 finished with value: 0.8143356313455961 and parameters: {'w0': 0.7258534548331113, 'w1': 0.2060972807358816}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,493] Trial 830 finished with value: 0.8129017580861913 and parameters: {'w0': 0.3532983143785933, 'w1': 0.24017895062825936}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,524] Trial 838 finished with value: 0.8143394462596122 and parameters: {'w0': 0.7287995262543109, 'w1': 0.2079554992423275}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,586] Trial 835 finished with value: 0.8143395800468571 and parameters: {'w0': 0.7300770387643438, 'w1': 0.20669377022178761}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,610] Trial 839 finished with value: 0.8143413466502069 and parameters: {'w0': 0.7324026707235155, 'w1': 0.20650925380860716}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,629] Trial 840 finished with value: 0.8143463737177934 and parameters: {'w0': 0.7330888855957924, 'w1': 0.21503612257328125}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:49,887] Trial 841 finished with value: 0.8143434468515507 and parameters: {'w0': 0.7290043626974573, 'w1': 0.2141084265627682}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,106] Trial 842 finished with value: 0.8142622212244437 and parameters: {'w0': 0.6609012378202186, 'w1': 0.22090539641869902}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,280] Trial 844 finished with value: 0.8143469286421829 and parameters: {'w0': 0.8052820136718951, 'w1': 0.19175069645857973}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,479] Trial 847 finished with value: 0.8143480271530601 and parameters: {'w0': 0.8015535591271805, 'w1': 0.1937244248598147}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,528] Trial 846 finished with value: 0.8143481948485423 and parameters: {'w0': 0.7993951535317165, 'w1': 0.1960878580551535}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,530] Trial 849 finished with value: 0.8143489619235371 and parameters: {'w0': 0.7978811230814546, 'w1': 0.19603710267061544}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,549] Trial 850 finished with value: 0.8143481294578511 and parameters: {'w0': 0.8000158062007665, 'w1': 0.19553507023663028}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,562] Trial 843 finished with value: 0.8143475869260522 and parameters: {'w0': 0.8028346229670111, 'w1': 0.193425213351678}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,578] Trial 851 finished with value: 0.8143481602020228 and parameters: {'w0': 0.7996762073662562, 'w1': 0.19591707413231849}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,580] Trial 855 finished with value: 0.8143478380474001 and parameters: {'w0': 0.801455434863088, 'w1': 0.1946519515668025}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,617] Trial 848 finished with value: 0.8128629796133611 and parameters: {'w0': 0.3493702517634398, 'w1': 0.23870870006769587}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,632] Trial 856 finished with value: 0.8143475763791664 and parameters: {'w0': 0.802875561481357, 'w1': 0.193388992639705}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,634] Trial 854 finished with value: 0.813281550068126 and parameters: {'w0': 0.4188322421253451, 'w1': 0.22911195543593646}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,692] Trial 852 finished with value: 0.8143465725265882 and parameters: {'w0': 0.8069031945401602, 'w1': 0.1905419415040578}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,769] Trial 845 finished with value: 0.8143479342877318 and parameters: {'w0': 0.801274044112981, 'w1': 0.19451441292918908}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,784] Trial 853 finished with value: 0.8143469589644793 and parameters: {'w0': 0.8055946972053448, 'w1': 0.19138876976497185}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,792] Trial 857 finished with value: 0.8143475216935643 and parameters: {'w0': 0.8027499536243232, 'w1': 0.19370159129017214}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,881] Trial 858 finished with value: 0.8143473757774009 and parameters: {'w0': 0.8025311688901591, 'w1': 0.19423941430641706}. Best is trial 744 with value: 0.8143545472905166.
# [I 2024-11-10 15:53:50,910] Trial 859 finished with value: 0.8143479096080193 and parameters: {'w0': 0.8009254331953319, 'w1': 0.19507505562479666}. Best is trial 744 with value: 0.8143545472905166.

# %%
study.best_params
# Out:
# {'w0': 0.7713255047579537, 'w1': 0.20056971078865193}

# %%
study.best_value
# Out:
# 0.8143545472905166

# %%
weights = np.array([0.7726348139013947, 0.19979192880550867])
weights = np.append(weights, 1 - np.sum(weights))
weights
# Out:
# array([0.77263481, 0.19979193, 0.02757326])

# %%
# study = optuna.create_study(
#             study_name="blending",
#             direction="maximize")
# study.optimize(objective, timeout=60, n_jobs=N_JOBS)

# %%
# print("w6: ", 1 - np.sum(list(study.best_params.values())))

# %%
pred = np.round(np.sum((df_train[cfg["stack_features"]].to_numpy() * weights), axis=1), 10)

# %%
metric(df_train["target"], pred)
# Out:
# 0.8143545481342676

# %%
test = pd.read_parquet(DATA_PATH / "test_preproc_oof.parquet")
#test[cfg["stack_features"]] = test[cfg["stack_features"]].astype(np.float32)
test["target"] = np.round(np.sum((test[cfg["stack_features"]].to_numpy() * weights), axis=1), 10)
test[['id', 'target']].to_csv(f'blend3_2.csv', index=False)

# %%
cfg["stack_features"]
# Out:
# ['lamau_81425_full_dataset',
#  'lgb_8122_full_dataset',
#  'cb_8114_full_dataset',
#  'xgb_81325_full_dataset',
#  'lama_81298_full_dataset',
#  'lamann_autoint_8053_full_dataset',
#  'lamann_fttransformer_8050_full_dataset']

# %%
cols_to_consider = ["lamau_81425_full_dataset", "lama_stack_time_series", "xgb_81325_full_dataset"]
weights = np.array([0.15, 0.85])

# %%
test = pd.read_parquet(DATA_PATH / "test_preproc_oof.parquet")
lama_stack_pred = pd.read_csv("lama_stack_time_series.csv")
test["lama_stack_time_series"] = lama_stack_pred["target"]
test["target"] = np.round(np.sum((test[cols_to_consider].to_numpy() * weights), axis=1), 10)
test[['id', 'target']].to_csv(f'blend_stack_3.csv', index=False)

# %%
test[cols_to_consider].to_numpy()
# Out:
# array([[0.01422167, 0.01676077, 0.01310246, 0.01688302],
#        [0.26035836, 0.26014048, 0.22095208, 0.2367294 ],
#        [0.03843449, 0.04023904, 0.03368598, 0.03804932],
#        ...,
#        [0.00844403, 0.01244384, 0.00624904, 0.00835771],
#        [0.02531996, 0.03010638, 0.02247832, 0.02501185],
#        [0.01512659, 0.01911527, 0.01602159, 0.01462073]])

# %%
# res = pd.DataFrame()
# res[MODEL_NAME] = oof[:, 1]
# res.to_csv(MODEL_DIR / "oof.csv", index=False)
# #joblib.dump(model, MODEL_DIR / f"{MODEL_NAME}.joblib")

# with (MODEL_DIR / "params.yaml").open("w") as f:
#     yaml.dump(model.params, f)

# with (MODEL_DIR / "score.txt").open("w") as f:
#     print("OOF:", metric(y_train, oof), file=f)
    
# test = pd.read_parquet(DATA_PATH / "test_preproc_2.parquet")
# test["target"] = model.predict(test[cfg["selected_features"] + cat_columns])[:, 1]
# test[['id', 'target']].to_csv(MODEL_DIR / f'{MODEL_NAME}.csv', index=False)

# %%
test = pd.read_parquet(DATA_PATH / "test_preproc_oof.parquet")
test[cfg["stack_features"]] = test[cfg["stack_features"]].astype(np.float32)
test["target"] = model.predict(test[cfg["selected_features"] + cfg["stack_features"] + cat_columns])[:, 1]
test[['id', 'target']].to_csv(f'{MODEL_NAME}.csv', index=False)

# %%
model.model.get_feature_scores()[:50]
# Out:
#                     Feature    Importance
# 0    lamau_814_full_dataset  78048.337071
# 1    xgb_81325_full_dataset  29297.001751
# 2   lama_81298_full_dataset  24098.444188
# 3               feature_162   1398.695796
# 4                feature_24   1321.674997
# 5                feature_18   1298.269506
# 6                feature_26   1290.120701
# 7               feature_145   1287.683197
# 8                feature_78   1279.916003
# 9                feature_36   1248.758602
# 10              feature_112   1228.811199
# 11                feature_9   1190.729637
# 12              feature_141   1140.620801
# 13               feature_75   1127.175495
# 14               feature_79   1114.103202
# 15               feature_62   1110.960901
# 16               feature_35   1088.471595
# 17               feature_44   1078.257104
# 18              feature_168   1069.888995
# 19              feature_148   1055.762701
# 20              feature_147   1051.141966
# 21               feature_76   1041.521295
# 22               feature_20   1029.698003
# 23              feature_157    998.859297
# 24               feature_33    993.189499
# 25              feature_133    992.890409
# 26               feature_59    988.289097
# 27               feature_46    978.601000
# 28               feature_14    968.263297
# 29               feature_43    967.263209
# 30              feature_142    953.593235
# 31               feature_83    951.608026
# 32               feature_96    936.340199
# 33    lgb_8122_full_dataset    899.356003
# 34              feature_126    894.646700
# 35              feature_100    889.852299
# 36               feature_55    889.369598
# 37              feature_183    882.159472
# 38              feature_127    853.308690
# 39              feature_153    835.863204
# 40               feature_87    802.161905
# 41                feature_8    801.556602
# 42              feature_103    793.046144
# 43               feature_29    783.742097
# 44              feature_134    777.999600
# 45               feature_11    771.673395
# 46               feature_66    770.873203
# 47               feature_72    722.490300
# 48               feature_21    675.958407
# 49               feature_25    664.108699

# %%
imp = pd.DataFrame().assign(names=model.models[0].feature_names_, imp=model.models[0].feature_importances_)

# %%
imp.sort_values(by="imp", ascending=False).reset_index(drop=True).query("names == 'feature_185'")
# Out:
#           names  imp
# 61  feature_185  0.0

# %%
cat_columns
# Out:
# ['feature_7',
#  'feature_31',
#  'feature_60',
#  'feature_61',
#  'feature_71',
#  'feature_109',
#  'feature_122',
#  'feature_156',
#  'feature_163',
#  'feature_167',
#  'feature_179',
#  'feature_185']

# %% [markdown]
# ## With Time series cross val

# %%
metric = RocAuc()

# %%
df_train = df_train.sort_values(by="id").reset_index(drop=True)
X_train, y_train = df_train[cfg["selected_features"] + cat_columns], df_train["target"]

# %%
model = LightGBMClassification(n_jobs=16, time_series=True)
model.tune(X_train, y_train, metric, timeout=60 * 60, categorical_features=cat_columns)
oof = model.fit(X_train, y_train, categorical_features=cat_columns)

print(metric(y_train, oof))
# Out:
# [2024-11-07 08:27:33,388] - [   START    ] - Tuning LightGBMClassification
# [2024-11-07 08:27:40,118] - [   OPTUNA   ] - Trial 0. New best score 0.7903405446081995 with parameters {'max_depth': 6, 'num_leaves': 488, 'min_data_in_leaf': 188, 'bagging_fraction': 0.7993292420985183, 'bagging_freq': 0, 'feature_fraction': 0.49359671220172163, 'lambda_l1': 0.5808361216819946, 'lambda_l2': 8.661761457749352, 'min_gain_to_split': 12.022300234864176, 'is_unbalance': True, 'num_iterations': 2}
# [2024-11-07 08:28:03,043] - [   OPTUNA   ] - Trial 2. New best score 0.7913515589848906 with parameters {'max_depth': 5, 'num_leaves': 194, 'min_data_in_leaf': 117, 'bagging_fraction': 0.8925879806965068, 'bagging_freq': 0, 'feature_fraction': 0.708540663048167, 'lambda_l1': 5.924145688620425, 'lambda_l2': 0.46450412719997725, 'min_gain_to_split': 12.150897038028766, 'is_unbalance': True, 'num_iterations': 2}
# [2024-11-07 08:28:12,225] - [   OPTUNA   ] - Trial 3. New best score 0.8048686053278628 with parameters {'max_depth': 16, 'num_leaves': 495, 'min_data_in_leaf': 207, 'bagging_fraction': 0.6523068845866853, 'bagging_freq': 0, 'feature_fraction': 0.8105398159072941, 'lambda_l1': 4.4015249373960135, 'lambda_l2': 1.2203823484477883, 'min_gain_to_split': 9.903538202225404, 'is_unbalance': False, 'num_iterations': 201}
# [2024-11-07 08:28:27,946] - [   OPTUNA   ] - Trial 5. New best score 0.805775359050857 with parameters {'max_depth': 15, 'num_leaves': 54, 'min_data_in_leaf': 51, 'bagging_fraction': 0.522613644455269, 'bagging_freq': 0, 'feature_fraction': 0.6332063738136893, 'lambda_l1': 2.713490317738959, 'lambda_l2': 8.287375091519294, 'min_gain_to_split': 7.135066533871786, 'is_unbalance': False, 'num_iterations': 219}
# [2024-11-07 08:30:01,873] - [   OPTUNA   ] - Trial 13. New best score 0.8069467403107815 with parameters {'max_depth': 12, 'num_leaves': 120, 'min_data_in_leaf': 83, 'bagging_fraction': 0.5973813098180023, 'bagging_freq': 0, 'feature_fraction': 0.6464487752219038, 'lambda_l1': 1.815539729792131, 'lambda_l2': 9.653379460654552, 'min_gain_to_split': 5.109079440883124, 'is_unbalance': False, 'num_iterations': 194}
# [2024-11-07 08:30:23,656] - [   OPTUNA   ] - Trial 15. New best score 0.8079174231410097 with parameters {'max_depth': 9, 'num_leaves': 123, 'min_data_in_leaf': 79, 'bagging_fraction': 0.6696558155271586, 'bagging_freq': 0, 'feature_fraction': 0.41254813989004224, 'lambda_l1': 1.5400879612744933, 'lambda_l2': 6.428485487443978, 'min_gain_to_split': 3.4073761639683475, 'is_unbalance': False, 'num_iterations': 221}
# [2024-11-07 08:30:47,866] - [   OPTUNA   ] - Trial 17. New best score 0.8080338307668665 with parameters {'max_depth': 9, 'num_leaves': 177, 'min_data_in_leaf': 149, 'bagging_fraction': 0.7020257462335121, 'bagging_freq': 0, 'feature_fraction': 0.4001314682445803, 'lambda_l1': 4.277484898844048, 'lambda_l2': 5.915176709957256, 'min_gain_to_split': 2.630193834916201, 'is_unbalance': False, 'num_iterations': 247}
# [2024-11-07 08:32:56,360] - [   OPTUNA   ] - Trial 26. New best score 0.8083158418056456 with parameters {'max_depth': 13, 'num_leaves': 120, 'min_data_in_leaf': 166, 'bagging_fraction': 0.8112271899455036, 'bagging_freq': 20, 'feature_fraction': 0.5385502023308056, 'lambda_l1': 1.3349604628055485, 'lambda_l2': 8.855392863089838, 'min_gain_to_split': 0.42505008659048693, 'is_unbalance': False, 'num_iterations': 206}
# [2024-11-07 08:33:39,494] - [   OPTUNA   ] - Trial 28. New best score 0.8085529083857821 with parameters {'max_depth': 14, 'num_leaves': 75, 'min_data_in_leaf': 170, 'bagging_fraction': 0.8264267643219445, 'bagging_freq': 20, 'feature_fraction': 0.5742524097970673, 'lambda_l1': 1.2310934175206736, 'lambda_l2': 8.969396792235317, 'min_gain_to_split': 0.16644360284870074, 'is_unbalance': False, 'num_iterations': 211}
# [2024-11-07 08:35:41,908] - [   OPTUNA   ] - Trial 35. New best score 0.8085624905981069 with parameters {'max_depth': 13, 'num_leaves': 45, 'min_data_in_leaf': 179, 'bagging_fraction': 0.9090867052918509, 'bagging_freq': 20, 'feature_fraction': 0.5986896700241908, 'lambda_l1': 1.0457599526213117, 'lambda_l2': 8.511810626751942, 'min_gain_to_split': 1.6394745612739139, 'is_unbalance': False, 'num_iterations': 242}
# [2024-11-07 08:36:11,789] - [   OPTUNA   ] - Trial 37. New best score 0.8086060147129036 with parameters {'max_depth': 15, 'num_leaves': 146, 'min_data_in_leaf': 131, 'bagging_fraction': 0.9727869256250319, 'bagging_freq': 20, 'feature_fraction': 0.594412726250827, 'lambda_l1': 1.3076349982497943, 'lambda_l2': 8.42304491740083, 'min_gain_to_split': 1.95638379105971, 'is_unbalance': False, 'num_iterations': 180}
# [2024-11-07 08:37:31,532] - [   OPTUNA   ] - Trial 42. New best score 0.8086748450733487 with parameters {'max_depth': 11, 'num_leaves': 95, 'min_data_in_leaf': 155, 'bagging_fraction': 0.9696680239166591, 'bagging_freq': 20, 'feature_fraction': 0.5068877996580057, 'lambda_l1': 0.3880584908457285, 'lambda_l2': 9.519643874182023, 'min_gain_to_split': 1.5176677728376484, 'is_unbalance': False, 'num_iterations': 225}
# [2024-11-07 08:43:11,113] - [   OPTUNA   ] - Trial 63. New best score 0.8087325744854885 with parameters {'max_depth': 16, 'num_leaves': 160, 'min_data_in_leaf': 166, 'bagging_fraction': 0.936885833403046, 'bagging_freq': 20, 'feature_fraction': 0.4498188675696397, 'lambda_l1': 1.1357746192947442, 'lambda_l2': 7.7534455607773385, 'min_gain_to_split': 2.069412187433082, 'is_unbalance': False, 'num_iterations': 207}
# [2024-11-07 08:45:27,863] - [   OPTUNA   ] - Trial 71. New best score 0.809046586456055 with parameters {'max_depth': 10, 'num_leaves': 153, 'min_data_in_leaf': 160, 'bagging_fraction': 0.9135728904594532, 'bagging_freq': 10, 'feature_fraction': 0.506921563666065, 'lambda_l1': 0.6725410135999423, 'lambda_l2': 8.841591608898721, 'min_gain_to_split': 1.6964405734320749, 'is_unbalance': False, 'num_iterations': 237}
# [2024-11-07 08:51:41,348] - [   OPTUNA   ] - Trial 91. New best score 0.8092009955871362 with parameters {'max_depth': 8, 'num_leaves': 331, 'min_data_in_leaf': 57, 'bagging_fraction': 0.9120914616559199, 'bagging_freq': 10, 'feature_fraction': 0.43368773726287124, 'lambda_l1': 3.8666345262680837, 'lambda_l2': 8.173281721666852, 'min_gain_to_split': 0.7062609644931823, 'is_unbalance': False, 'num_iterations': 313}
# [2024-11-07 09:24:15,316] - [   OPTUNA   ] - Trial 184. New best score 0.8092209952891476 with parameters {'max_depth': 8, 'num_leaves': 258, 'min_data_in_leaf': 21, 'bagging_fraction': 0.8833000021442096, 'bagging_freq': 10, 'feature_fraction': 0.44326798567844145, 'lambda_l1': 1.7734419425628303, 'lambda_l2': 8.481446649565262, 'min_gain_to_split': 0.19263364585511303, 'is_unbalance': False, 'num_iterations': 294}
# [2024-11-07 09:27:54,872] - [   OPTUNA   ] - 195 trials completed
# [2024-11-07 09:27:54,874] - [BEST PARAMS ] - {'objective_type': 'binary', 'boosting': 'gbdt', 'num_iterations': 294, 'max_depth': 8, 'learning_rate': 0.03, 'num_leaves': 258, 'min_data_in_leaf': 21, 'bagging_fraction': 0.8833000021442096, 'bagging_freq': 10, 'feature_fraction': 0.44326798567844145, 'early_stopping_round': 100, 'lambda_l1': 1.7734419425628303, 'lambda_l2': 8.481446649565262, 'min_gain_to_split': 0.19263364585511303, 'num_threads': 16, 'random_state': 42, 'is_unbalance': False, 'num_classes': 1, 'verbose': -1}
# [2024-11-07 09:27:54,875] - [    END     ] - Tuning LightGBMClassification
# [2024-11-07 09:27:54,877] - [   START    ] - Fitting LightGBMClassification
# [2024-11-07 09:27:54,892] - [    FIT     ] - LightGBMClassification fold 0
# [2024-11-07 09:27:56,881] - [    FIT     ] - LightGBMClassification fold 1
# [2024-11-07 09:27:59,788] - [    FIT     ] - LightGBMClassification fold 2
# [2024-11-07 09:28:04,156] - [    FIT     ] - LightGBMClassification fold 3
# [2024-11-07 09:28:09,145] - [    FIT     ] - LightGBMClassification fold 4
# [2024-11-07 09:28:14,959] - [    END     ] - Fitting LightGBMClassification
# None

# %%
none_oofs_idx = oof[np.any(np.isnan(oof), axis=1)].shape[0]

# %%
metric(y_train[none_oofs_idx:], oof[none_oofs_idx:])
# Out:
# 0.8095227594190041

# %%
MODEL_NAME = "lgb_8095_full_dataset_time_series"
MODEL_DIR = Path(f"../../../data/models/{MODEL_NAME}")
MODEL_DIR.mkdir(exist_ok=True)

# %%
res = pd.DataFrame()
res[MODEL_NAME] = oof[none_oofs_idx:, 1]
res.to_csv(MODEL_DIR / "oof.csv", index=False)
joblib.dump(model, MODEL_DIR / f"{MODEL_NAME}.joblib")

with (MODEL_DIR / "params.yaml").open("w") as f:
    yaml.dump(model.params, f)

with (MODEL_DIR / "score.txt").open("w") as f:
    print("OOF:", metric(y_train, oof), file=f)
    
test = pd.read_parquet(DATA_PATH / "test_preproc_2.parquet")
test["target"] = model.predict(test[cfg["selected_features"] + cat_columns])[:, 1]
test[['id', 'target']].to_csv(MODEL_DIR / f'{MODEL_NAME}.csv', index=False)

# %% [markdown]
# ## TEST
# **81.22112399468679**

# %% [markdown]
# ## Inference

# %%
test = pd.read_parquet(DATA_PATH / "test_preproc_2.parquet")
test["target"] = model.predict(test[cfg["selected_features"] + cat_columns])[:, 1]
test[['id', 'target']].to_csv('lgb_813.csv', index=False)

# %%
pred_1 = pd.read_csv("lama_utilized.csv")
pred_2 = pd.read_csv("lgmb_oe_ohe_cols_0805.csv")
pred_3 = pd.read_csv("catboost_ts.csv")

# %%
pred_1["target"] = 0.6 * pred_1["target"] + 0.2 * pred_2["target"] + 0.2 * pred_3["target"]

# %%
pred_1.to_csv("blend.csv", index=False)

# %%
MODEL_DIR.open?
# Out:
# Signature:
# MODEL_DIR.open(
#     mode='r',
#     buffering=-1,
#     encoding=None,
#     errors=None,
#     newline=None,
# )
# Docstring:
# Open the file pointed by this path and return a file object, as
# the built-in open() function does.
# File:      /usr/lib/python3.10/pathlib.py
# Type:      method
